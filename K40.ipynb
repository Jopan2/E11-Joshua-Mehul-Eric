# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np 
import scipy.signal as fp

# %%
spectra = np.loadtxt("GPS_GUI_Spectrum_Data_2023-04-28_14:42:07.csv",skiprows=1, delimiter=",")
spectra = np.delete(spectra,0,1)
spectraplot = spectra.sum(axis=0)

spectraplot
plt.plot(spectraplot)
plt.yscale('log')
